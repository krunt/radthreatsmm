# %%
import pandas as pd
import pyarrow.parquet as pq
import os
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import pywt
import numpy as np
from scipy.signal import resample
from scipy import signal
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from sklearn.metrics import roc_curve

from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from keras import layers
from keras import models
from keras.callbacks import ModelCheckpoint

from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D

from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting

from scipy.signal import find_peaks, peak_widths, peak_prominences
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pyarrow.parquet as pq
import gc
import pywt
from statsmodels.robust import mad
import scipy
from scipy import signal
from scipy.signal import butter, find_peaks, find_peaks_cwt
from scipy import optimize, misc

import warnings

# Suppress pandas future warnings, I am using different library versions locally
# that do not raise warnings.
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# /home/alexey/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
#dat = pd.read_csv("training/109693.csv", header=None)
#dat = pd.read_csv("training/104902.csv", header=None)
#dat = pd.read_csv("testing/200002.csv", header=None)
trainingAnswers=pd.read_csv("trainingAnswers.csv")

# %%
plt.figure(figsize=(16,8))
plt.plot(np.cumsum(dat[0])[32300:34000]*1e-6, dat[1][32300:34000])
# Out:
# /usr/local/lib/python3.5/dist-packages/pandas/core/computation/check.py:19: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.6.1
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
sInfo = pd.read_csv("SourceInfov3/SourceData.csv")

# %%
dat1 = sInfo[(sInfo["SourceType"] == "WGPu") & (sInfo["SourceID"] == 1) & (sInfo["Shielding"] == 0)]
dat2 = sInfo[(sInfo["SourceType"] == "WGPu") & (sInfo["SourceID"] == 1) & (sInfo["Shielding"] == 1)]

# %%
plt.plot(sInfo[(sInfo["SourceID"] == 5) & (sInfo["Shielding"] == 0)]["PhotonEnergy"], 
         sInfo[(sInfo["SourceID"] == 5) & (sInfo["Shielding"] == 0)]["CountRate"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-96e38f827139> in <module>
# ----> 1 plt.plot(sInfo[(sInfo["SourceID"] == 5) & (sInfo["Shielding"] == 0)]["PhotonEnergy"],
#       2          sInfo[(sInfo["SourceID"] == 5) & (sInfo["Shielding"] == 0)]["CountRate"])
#
# NameError: name 'sInfo' is not defined

# %%
pArr = sInfo[(sInfo["SourceID"] == 1) & (sInfo["Shielding"] == 0) & (sInfo["PhotonEnergy"] < 500)]["PhotonEnergy"]
sig = sInfo[(sInfo["SourceID"] == 1) & (sInfo["Shielding"] == 0) & (sInfo["PhotonEnergy"] < 500)]["CountRate"]
sig = denoise_signal(sig)
peaks, _ = find_peaks(sig)
plt.plot(pArr, sig)
plt.plot(peaks, sig[peaks], 'x')

# %%
plt.figure(figsize=(16,8))
plt.plot(np.cumsum(dat[0])*1e-6, dat[1])

# %%
dat = pd.read_csv("training/105709.csv", header=None)
d0=dat[0]*1e-6
d1=np.cumsum(d0)
d2=dat[1]

# %%
for i in [30,1]: #range(45):
    #plt.figure();
    plt.title("%d" % (0 + i))
    dind = np.argwhere((d1 > (0 + i)) & (d1 < (0 + i + 1))).flatten()
    d3 = d2[dind]
    plt.hist(d3,bins=200);
    #v0 = np.histogram(d3[20+i],bins=200)[0]
    #v1 = np.histogram(d3[20+i+1],bins=200)[0]
    #v2 = np.abs(v0-v1)
    #plt.plot(v2)

# %% [markdown]
# dind = np.argwhere((d1 > (0 + i)) & (d1 < (0 + i + 1))).flatten()
# d3 = d2[dind]

# %%
i = 32
dind = np.argwhere((d1 > (0 + i)) & (d1 < (0 + i + 2))).flatten() 
d3 = d2[dind]
hist = np.histogram(d3, bins=200)[0]

# %%
plt.plot(hist)

# %%
#d4 = d0[dind]
d4 = d0 #[dind]
hist_t = np.histogram(np.cumsum(d4), bins=55)[0]

# %%
plt.plot(hist_t)
#plt.plot(d0)
np.cumsum(d4).values[-1]
# Out:
# 55.15361800000005

# %%
np.histogram(np.cumsum(d4),10)
# Out:
# (array([153, 187, 175, 171, 168, 203, 186, 251, 254, 292]),
#  array([0.002686 , 0.2025224, 0.4023588, 0.6021952, 0.8020316, 1.001868 ,
#         1.2017044, 1.4015408, 1.6013772, 1.8012136, 2.00105  ]))

# %%
def PowerLaw(p, x):
    return p[0]*x**(p[1])

# %%
x = np.linspace(620, 660, 300)
unknown_spectra = hist.astype(np.float64)
errfunc = lambda p, x, unknown_spectra : PowerLaw(p, x) -  unknown_spectra
p0 = [ -0.4,  0.15]
indices_before_onset = 60
p1, success = optimize.leastsq(errfunc, p0, args=(x[0:indices_before_onset], ( np.array(unknown_spectra[0:indices_before_onset]) )), maxfev=500000)
unknown_spectra -= PowerLaw(p1, x)
plt.plot(unknown_spectra)
#print(unknown_spectra)

# %%
def maddest(d, axis=None):
    """
    Mean Absolute Deviation
    """
    return np.mean(np.absolute(d - np.mean(d, axis)), axis)

def denoise_signal( x, wavelet='db4', level=1):
    """
    1. Adapted from waveletSmooth function found here:
    http://connor-johnson.com/2016/01/24/using-pywavelets-to-remove-high-frequency-noise/
    2. Threshold equation and using hard mode in threshold as mentioned
    in section '3.2 denoising based on optimized singular values' from paper by Tomas Vantuch:
    http://dspace.vsb.cz/bitstream/handle/10084/133114/VAN431_FEI_P1807_1801V001_2018.pdf
    """
    
    # Decompose to get the wavelet coefficients
    coeff = pywt.wavedec( x, wavelet, mode="per" )
    
    # Calculate sigma for threshold as defined in http://dspace.vsb.cz/bitstream/handle/10084/133114/VAN431_FEI_P1807_1801V001_2018.pdf
    # As noted by @harshit92 MAD referred to in the paper is Mean Absolute Deviation not Median Absolute Deviation
    sigma = (1/0.6745) * maddest( coeff[-level] )

    # Calculte the univeral threshold
    uthresh = sigma * np.sqrt( 2*np.log( len( x ) ) )
    coeff[1:] = ( pywt.threshold( i, value=uthresh, mode='hard' ) for i in coeff[1:] )
    
    # Reconstruct the signal using the thresholded coefficients
    return pywt.waverec( coeff, wavelet, mode='per' )

# %%
fileId = 102105
dat = pd.read_csv("training/%d.csv" % (fileId), header=None)
dat[0]=dat[0]*1e-6
dat[0]=np.cumsum(dat[0])
#dat = dat[dat[1] < 500]
#dat = dat.reset_index(drop=True)
d1=dat[0]
d2=dat[1]

tmax = d1.values[-1]
timeHist = np.histogram(d1, bins=1024)[0]
timeHist = denoise_signal(timeHist)
peaks, _ = find_peaks(timeHist, prominence=(5))
peaksS = peaks / 1024 * tmax

plt.figure(figsize=(16,8))
for ts in peaksS:
    if ts < 30.0 or ts > tmax - 2:
        continue
    plt.figure()
    plt.title("peak_%d/%f" % (fileId, ts))
    w = 0.5
    dind = np.argwhere((d1 > (ts - w/2)) & (d1 < (ts + w/2))).flatten() 
    d3 = d2[dind]
    #d3 = d2
    hist, bins = np.histogram(d3, bins=128)
    hist = denoise_signal(hist)
    peaks, _ = find_peaks(hist, prominence=(5))
    plt.plot(bins[:128],hist)
    plt.plot(peaks / 128 * bins[-1], hist[peaks], 'x')
    print("peak_%f" % ts)
    print(peaks / 128 * bins[-1])
    #pWidths = peak_widths(hist, peaks)[0]
    #print(pWidths)
    #pProminences = peak_prominences(hist, peaks)[0]
    #print(pProminences)
# Out:
# peak_33.222298
# [ 62.55234375 166.80625   ]
# peak_40.869504
# [ 53.784375 107.56875  197.209375]

# %%
np.argmin(np.abs([]-30))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-addacbd4d4b4> in <module>
# ----> 1 np.argmin(np.abs([]-30))
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'

# %%
start=100032
for i in range(10):
    id = start + i
    sId = trainingAnswers[trainingAnswers["RunID"] == id]["SourceID"]
    sTime = trainingAnswers[trainingAnswers["RunID"] == id]["SourceTime"]
    plt.figure()
    plt.title("%d/%d/%f" % (id, sId, sTime))
    dat = pd.read_csv("training/%d.csv" % (id), header=None)
    d0=dat[0]*1e-6
    d1=np.cumsum(d0)
    d2=dat[1]

    #i = 40
    #dind = np.argwhere((d1 > (0 + i)) & (d1 < (0 + i + 1))).flatten() 
    #d3 = d2[dind]
    hist = np.histogram(d1, bins=1024)[0]
    hist = denoise_signal(hist)
    peaks, _ = find_peaks(hist, prominence=(5))
    plt.plot(np.arange(1024) / 1024 * d1.values[-1], hist)
    plt.plot(peaks / 1024 * d1.values[-1], hist[peaks], 'x')

# %%
id=107466
dat = pd.read_csv("training/%d.csv" % (id), header=None)
d0=dat[0]*1e-6
d1=np.cumsum(d0)

for i in range(10):
    sId = trainingAnswers[trainingAnswers["RunID"] == id]["SourceID"]
    sTime = trainingAnswers[trainingAnswers["RunID"] == id]["SourceTime"]
    plt.figure()
    plt.title("%d/%d/%f" % (id, i, 0))
    
    ddat = d1[(dat[1] > i*100) & (dat[1] < (i+1)*100)]
    d11 = ddat
    
    print(d11.shape)

    hist = np.histogram(d11, bins=128)[0]
    hist = denoise_signal(hist)
    #peaks, _ = find_peaks(hist, prominence=(5))
    plt.plot(np.arange(128) / 128 * d11.values[-1], hist)
# Out:
# (17875,)
# (17780,)
# (8391,)
# (4593,)
# (2389,)
# (2120,)
# (1717,)
# (1096,)
# (922,)
# (917,)

# %%
start=215825
for i in range(10):
    id = start + i
    #sId = trainingAnswers[trainingAnswers["RunID"] == id]["SourceID"]
    #sTime = trainingAnswers[trainingAnswers["RunID"] == id]["SourceTime"]
    plt.figure()
    plt.title("%d/%d/%f" % (id, 1, 1))
    dat = pd.read_csv("testing/%d.csv" % (id), header=None)
    d0=dat[0]*1e-6
    d1=np.cumsum(d0)
    d2=dat[1]

    #i = 40
    #dind = np.argwhere((d1 > (0 + i)) & (d1 < (0 + i + 1))).flatten() 
    #d3 = d2[dind]
    hist = np.histogram(d1, bins=1024)[0]
    hist = denoise_signal(hist)
    peaks, _ = find_peaks(hist, prominence=(5))
    plt.plot(np.arange(1024) / 1024 * d1.values[-1], hist)
    plt.plot(peaks / 1024 * d1.values[-1], hist[peaks], 'x')

# %%
id=107112
dat = pd.read_csv("training/%d.csv" % (id), header=None)
sId = trainingAnswers[trainingAnswers["RunID"] == id]["SourceID"]
sTime = trainingAnswers[trainingAnswers["RunID"] == id]["SourceTime"]
d0=dat[0]*1e-6
d1=np.cumsum(d0)
d2=dat[1]
tscale=1
invtscale=1/tscale
tmax=int(d1.values[-1]*tscale)

bins=128*5
zmat = np.zeros((tmax+1,bins))

ebins = np.linspace(0,2500,bins+1)

ymat, xmat = np.meshgrid(ebins,range(tmax+1))

fig, (ax0) = plt.subplots(nrows=1)

fig.set_figheight(12)
fig.set_figwidth(16)
plt.title("%d/%d/%f" % (id,sId,tscale*sTime))

for i in range(tmax):
    dind = np.argwhere((d1 > (i)*invtscale) & (d1 < (i + 1)*invtscale)).flatten() 
    d3 = d2[dind]
    hist = np.histogram(d3, bins=ebins)[0]
    #hist = denoise_signal(hist)
    zmat[i,:] = hist

im = ax0.pcolormesh(xmat, ymat, zmat)
fig.colorbar(im, ax=ax0)
plt.show()

# %%
id=102184
dat = pd.read_csv("testing/%d.csv" % (id), header=None)
sId = 0
sTime = 0
d0=dat[0]*1e-6
d1=np.cumsum(d0)
d2=dat[1]
tmax=int(d1.values[-1])

bins=128*5
zmat = np.zeros((tmax+1,bins))

ebins = np.linspace(0,2500,bins)

ymat, xmat = np.meshgrid(ebins,range(tmax+1))

fig, (ax0) = plt.subplots(nrows=1)

fig.set_figheight(12)
fig.set_figwidth(16)
plt.title("%d/%d/%f" % (id,sId,sTime))

for i in range(tmax):
    dind = np.argwhere((d1 > (i)) & (d1 < (i + 1))).flatten() 
    d3 = d2[dind]
    hist = np.histogram(d3, bins=ebins)[0]
    hist = denoise_signal(hist)
    zmat[i,:] = hist

im = ax0.pcolormesh(xmat, ymat, zmat)
fig.colorbar(im, ax=ax0)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-5e09b3a9b9c2> in <module>
#       1 id=102184
# ----> 2 dat = pd.read_csv("testing/%d.csv" % (id), header=None)
#       3 sId = 0
#       4 sTime = 0
#       5 d0=dat[0]*1e-6
#
# ...

# %%
fileId = 108533
dat = pd.read_csv("training/%d.csv" % (fileId), header=None)
dat[0]=dat[0]*1e-6
dat[0]=np.cumsum(dat[0])
d1=dat[0]
d2=dat[1]

tmax = d1.values[-1]
timeHist = np.histogram(d1, bins=1024)[0]
timeHist = denoise_signal(timeHist)
peaks, _ = find_peaks(timeHist, prominence=(5))
peaksS = peaks / 1024 * tmax

plt.figure(figsize=(16,8))
for ts in [257.5,297.6]:
    plt.figure()
    plt.title("%d/%f" % (fileId, ts))
    w = 0.5
    dind = np.argwhere((d1 > (ts - w/2)) & (d1 < (ts + w/2))).flatten() 
    d3 = d2[dind]
    hist, bins = np.histogram(d3, bins=128)
    hist = denoise_signal(hist)
    plt.plot(bins[:128],hist)
